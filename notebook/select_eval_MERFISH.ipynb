# %%
# !python /root/autodl-tmp/MultiGPS/main.py \
--adata_file '/root/autodl-tmp/MultiGPS/notebook/MERFISH/Zhuang-ABCA-2.005_processed.h5ad' \
--task_name Zhuang-2005 \
--seed 114514 \
--tasks recon,cls,coordination \
--saving_dir '/root/autodl-tmp/MultiGPS/test/Zhuang-2005/index/' \
--log_dir '/root/autodl-tmp/MultiGPS/test/Zhuang-2005/log/' \
--device cuda:0 \
--epoch 1000 \
--layer log1pcpm \
--val \
--record 100 \
--activation tanh \
--batch_size 1024 \
--learning_rate 0.001
# Out:
# MultiGPS start!
#   0%|                                                  | 0/1000 [00:00<?, ?it/s]Epoch 0 Started
# Task recon Loss in train: 1.0021835565567017
# Task recon Loss in val: 1.0025314092636108
# Task cls Loss in train: 3.380542278289795
# Task cls Loss in val: 2.8850719928741455
# Task coo Loss in train: 10.3375825881958
# Task coo Loss in val: 4.170200347900391
#   0%|                                          | 1/1000 [00:00<12:37,  1.32it/s]Epoch 1 Started
# Task recon Loss in train: 0.9838125705718994
# Task recon Loss in val: 0.9572177529335022
# Task cls Loss in train: 2.558562994003296
# Task cls Loss in val: 2.2992944717407227
# Task coo Loss in train: 1.402818202972412
# Task coo Loss in val: 0.5390757322311401
#   0%|                                          | 2/1000 [00:00<07:08,  2.33it/s]Epoch 2 Started
# Task recon Loss in train: 0.9641153812408447
# Task recon Loss in val: 0.9375181198120117
# Task cls Loss in train: 2.1363375186920166
# ...

# %%
# !python /root/autodl-tmp/MultiGPS/main.py \
--adata_file '/root/autodl-tmp/MultiGPS/notebook/MERFISH/Zhuang-ABCA-1.014_processed.h5ad' \
--task_name Zhuang-2005 \
--seed 114514 \
--tasks "recon,cls,coordination" \
--saving_dir '/root/autodl-tmp/MultiGPS/test/Zhuang-1014/index/' \
--log_dir '/root/autodl-tmp/MultiGPS/test/Zhuang-1014/log/' \
--device cuda:0 \
--epoch 1000 \
--layer log1pcpm \
--val \
--record 100 \
--activation tanh \
--batch_size 1024 \
--learning_rate 0.001
# Out:
# MultiGPS start!
#   0%|                                                  | 0/1000 [00:00<?, ?it/s]Epoch 0 Started
# Task recon Loss in train: 1.0014004707336426
# Task recon Loss in val: 1.0067296028137207
# Task cls Loss in train: 3.5254030227661133
# Task cls Loss in val: 3.0002596378326416
# Task coo Loss in train: 11.69140625
# Task coo Loss in val: 5.469943523406982
#   0%|                                          | 1/1000 [00:00<06:59,  2.38it/s]Epoch 1 Started
# Task recon Loss in train: 0.9794108271598816
# Task recon Loss in val: 0.9691383838653564
# Task cls Loss in train: 2.5692148208618164
# Task cls Loss in val: 2.308044195175171
# Task coo Loss in train: 2.2247629165649414
# Task coo Loss in val: 0.6869955658912659
#   0%|                                          | 2/1000 [00:00<04:54,  3.39it/s]Epoch 2 Started
# Task recon Loss in train: 0.9516412019729614
# Task recon Loss in val: 0.9411587119102478
# Task cls Loss in train: 2.0784080028533936
# ...

# %%
# !python /root/autodl-tmp/MultiGPS/eval.py \
--file_name "1014_self_eval" \
--gene_panel "/root/autodl-tmp/MultiGPS/test/Zhuang-1014/index/recon-cls-coordination-seed114514-Zhuang-2005-epoch:999.txt" \
--gene_number 32 \
--target_adata "/root/autodl-tmp/MultiGPS/notebook/MERFISH/Zhuang-ABCA-1.014_processed.h5ad" \
--output_dir "/root/autodl-tmp/MultiGPS/test/Zhuang-1014/eval_on_1014/" \
--seed 114514 \
--tasks 'cell_type,recon,spatial' \
--device cuda:0
# Out:
# Start!
# /root/miniconda3/lib/python3.10/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Selected Gene Number:32
# Selected Gene: ['ENSMUSG00000041378', 'ENSMUSG00000042453', 'ENSMUSG00000090063', 'ENSMUSG00000049001', 'ENSMUSG00000042793', 'ENSMUSG00000084890', 'ENSMUSG00000026424', 'ENSMUSG00000001119', 'ENSMUSG00000048332', 'ENSMUSG00000061524', 'ENSMUSG00000022836', 'ENSMUSG00000037428', 'ENSMUSG00000059456', 'ENSMUSG00000020061', 'ENSMUSG00000020902', 'ENSMUSG00000019929', 'ENSMUSG00000008734', 'ENSMUSG00000018634', 'ENSMUSG00000046982', 'ENSMUSG00000026249', 'ENSMUSG00000032087', 'ENSMUSG00000020734', 'ENSMUSG00000005672', 'ENSMUSG00000026787', 'ENSMUSG00000041324', 'ENSMUSG00000032368', 'ENSMUSG00000031075', 'ENSMUSG00000021614', 'ENSMUSG00000026830', 'ENSMUSG00000022148', 'ENSMUSG00000026395', 'ENSMUSG00000027168']
# ...

# %%
# !python /root/autodl-tmp/MultiGPS/eval.py \
--file_name "Zhuang2005_to_1014" \
--gene_panel "/root/autodl-tmp/MultiGPS/test/Zhuang-2005/index/recon-cls-coordination-seed114514-Zhuang-2005-epoch:999.txt" \
--gene_number 32 \
--target_adata "/root/autodl-tmp/MultiGPS/notebook/MERFISH/Zhuang-ABCA-1.014_processed.h5ad" \
--output_dir "/root/autodl-tmp/MultiGPS/test/Zhuang-2005/eval_on_1014/" \
--seed 114514 \
--tasks 'cell_type,recon,spatial' \
--device cuda:0
# Out:
# Start!
# /root/miniconda3/lib/python3.10/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Selected Gene Number:32
# Selected Gene: ['ENSMUSG00000032368', 'ENSMUSG00000020140', 'ENSMUSG00000027849', 'ENSMUSG00000059456', 'ENSMUSG00000037428', 'ENSMUSG00000049001', 'ENSMUSG00000003657', 'ENSMUSG00000001985', 'ENSMUSG00000090063', 'ENSMUSG00000041378', 'ENSMUSG00000047945', 'ENSMUSG00000033910', 'ENSMUSG00000037625', 'ENSMUSG00000033006', 'ENSMUSG00000050953', 'ENSMUSG00000075334', 'ENSMUSG00000055435', 'ENSMUSG00000040373', 'ENSMUSG00000026249', 'ENSMUSG00000019929', 'ENSMUSG00000005583', 'ENSMUSG00000038156', 'ENSMUSG00000020836', 'ENSMUSG00000038642', 'ENSMUSG00000025324', 'ENSMUSG00000040258', 'ENSMUSG00000043557', 'ENSMUSG00000018634', 'ENSMUSG00000030605', 'ENSMUSG00000047139', 'ENSMUSG00000045515', 'ENSMUSG00000020061']
# ...
